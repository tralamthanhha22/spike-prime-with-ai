# %%
! python -m pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\klh\appdata\local\python\pythoncore-3.11-64\lib\site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in c:\users\klh\appdata\local\python\pythoncore-3.11-64\lib\site-packages (from opencv-python) (2.4.2)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! python -m pip uninstall tensorflow

# %%
! python -m pip install tensorflow==2.12

# %%
! python -m pip uninstall serial
# Out:
# Collecting serial
#   Downloading serial-0.0.97-py2.py3-none-any.whl.metadata (889 bytes)
# Collecting future>=0.17.1 (from serial)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting pyyaml>=3.13 (from serial)
#   Downloading pyyaml-6.0.3-cp311-cp311-win_amd64.whl.metadata (2.4 kB)
# Collecting iso8601>=0.1.12 (from serial)
#   Downloading iso8601-2.1.0-py3-none-any.whl.metadata (3.7 kB)
# Downloading serial-0.0.97-py2.py3-none-any.whl (40 kB)
#    ---------------------------------------- 0.0/40.9 kB ? eta -:--:--
#    -------------------- ------------------- 20.5/40.9 kB ? eta -:--:--
#    ---------------------------------------- 40.9/40.9 kB 653.0 kB/s eta 0:00:00
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
#    ---------------------------------------- 0.0/491.3 kB ? eta -:--:--
#    --- ------------------------------------ 41.0/491.3 kB 2.0 MB/s eta 0:00:01
#    --------------- ------------------------ 184.3/491.3 kB 2.2 MB/s eta 0:00:01
#    ------------------------- -------------- 307.2/491.3 kB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 471.0/491.3 kB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 491.3/491.3 kB 2.8 MB/s eta 0:00:00
# Downloading iso8601-2.1.0-py3-none-any.whl (7.5 kB)
# Downloading pyyaml-6.0.3-cp311-cp311-win_amd64.whl (158 kB)
#    ---------------------------------------- 0.0/158.8 kB ? eta -:--:--
#    ---------------------------------------- 158.8/158.8 kB ? eta 0:00:00
# Installing collected packages: pyyaml, iso8601, future, serial
# Successfully installed future-1.0.0 iso8601-2.1.0 pyyaml-6.0.3 serial-0.0.97
#   WARNING: The scripts futurize.exe and pasteurize.exe are installed in 'c:\Users\KLH\AppData\Local\Python\pythoncore-3.11-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! python -m pip install pyserial

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
import serial
import time

# load model
model = load_model("keras_model.h5")

# labels
labels = open("labels.txt").read().splitlines()

# camera
cap = cv2.VideoCapture(0)

# kết nối SPIKE qua serial
ser = serial.Serial("COM3",115200)
time.sleep(2)

while True:
    ret, frame = cap.read()

    img = cv2.resize(frame,(224,224))
    img = np.asarray(img)
    img = img/255.0
    img = img.reshape(1,224,224,3)

    prediction = model.predict(img)
    index = np.argmax(prediction)
    label = labels[index]

    print(label)

    if label == "Go":
        ser.write(b"GO\n")

    if label == "Stop":
        ser.write(b"STOP\n")

    cv2.imshow("camera",frame)

    if cv2.waitKey(1)==27:
        break
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\KLH\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\ops\operation.py:317, in Operation.from_config(cls, config)
#     316 try:
# --> 317     return cls(**config)
#     318 except Exception as e:
#
# File c:\Users\KLH\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\layers\convolutional\depthwise_conv2d.py:120, in DepthwiseConv2D.__init__(self, kernel_size, strides, padding, depth_multiplier, data_format, dilation_rate, activation, use_bias, depthwise_initializer, bias_initializer, depthwise_regularizer, bias_regularizer, activity_regularizer, depthwise_constraint, bias_constraint, **kwargs)
#     101 def __init__(
#     102     self,
#     103     kernel_size,
#    (...)    118     **kwargs,
#     119 ):
# --> 120     super().__init__(
#     121         rank=2,
#     122         depth_multiplier=depth_multiplier,
#     123         kernel_size=kernel_size,
#     124         strides=strides,
#     125         padding=padding,
#     126         data_format=data_format,
#     127         dilation_rate=dilation_rate,
#     128         activation=activation,
#     129         use_bias=use_bias,
#     130         depthwise_initializer=depthwise_initializer,
#     131         bias_initializer=bias_initializer,
#     132         depthwise_regularizer=depthwise_regularizer,
#     133         bias_regularizer=bias_regularizer,
#     134         activity_regularizer=activity_regularizer,
#     135         depthwise_constraint=depthwise_constraint,
#     136         bias_constraint=bias_constraint,
#     137         **kwargs,
#     138     )
#
# File c:\Users\KLH\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\layers\convolutional\base_depthwise_conv.py:106, in BaseDepthwiseConv.__init__(self, rank, depth_multiplier, kernel_size, strides, padding, data_format, dilation_rate, activation, use_bias, depthwise_initializer, bias_initializer, depthwise_regularizer, bias_regularizer, activity_regularizer, depthwise_constraint, bias_constraint, trainable, name, **kwargs)
#      84 def __init__(
#      85     self,
#      86     rank,
#    (...)    104     **kwargs,
#     105 ):
# --> 106     super().__init__(
#     107         trainable=trainable,
#     108         name=name,
#     109         activity_regularizer=regularizers.get(activity_regularizer),
#     110         **kwargs,
#     111     )
#     112     self.rank = rank
#
# File c:\Users\KLH\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\layers\layer.py:294, in Layer.__init__(self, activity_regularizer, trainable, dtype, autocast, name, **kwargs)
#     293 if kwargs:
# --> 294     raise ValueError(
#     295         "Unrecognized keyword arguments "
#     296         f"passed to {self.__class__.__name__}: {kwargs}"
#     297     )
#     299 self._path = None  # Will be determined in `build_wrapper`
#
# ValueError: Unrecognized keyword arguments passed to DepthwiseConv2D: {'groups': 1}
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 8
#       5 import time
#       7 # load model
# ----> 8 model = load_model("keras_model.h5")
#      10 # labels
#      11 labels = open("labels.txt").read().splitlines()
#
# File c:\Users\KLH\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\saving\saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath,
#     198         custom_objects=custom_objects,
#     199         compile=compile,
#     200         safe_mode=safe_mode,
#     201     )
#     202 elif str(filepath).endswith(".keras"):
#     203     raise ValueError(
#     204         f"File not found: filepath={filepath}. "
#     205         "Please ensure the file is an accessible `.keras` "
#     206         "zip file."
#     207     )
#
# File c:\Users\KLH\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:137, in load_model_from_hdf5(filepath, custom_objects, compile, safe_mode)
#     135 safe_mode_scope = serialization_lib.SafeModeScope(safe_mode)
#     136 with legacy_scope, safe_mode_scope:
# --> 137     model = saving_utils.model_from_config(
#     138         model_config, custom_objects=custom_objects
#     139     )
#     141     # set weights
#     142     load_weights_from_hdf5_group(f["model_weights"], model)
#
# File c:\Users\KLH\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\legacy\saving\saving_utils.py:83, in model_from_config(config, custom_objects)
#      80         function_dict["config"]["closure"] = function_config[2]
#      81         config["config"]["function"] = function_dict
# ---> 83 return serialization.deserialize_keras_object(
#      84     config,
#      85     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      86     custom_objects=custom_objects,
#      87     printable_module_name="layer",
#      88 )
#
# File c:\Users\KLH\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\legacy\saving\serialization.py:488, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     485 custom_objects = custom_objects or {}
#     487 if "custom_objects" in arg_spec.args:
# --> 488     deserialized_obj = cls.from_config(
#     489         cls_config,
#     490         custom_objects={
#     491             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     492             **custom_objects,
#     493         },
#     494     )
#     495 else:
#     496     with object_registration.CustomObjectScope(custom_objects):
#
# File c:\Users\KLH\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\models\sequential.py:366, in Sequential.from_config(cls, config, custom_objects)
#     362 for layer_config in layer_configs:
#     363     if "module" not in layer_config:
#     364         # Legacy format deserialization (no "module" key)
#     365         # used for H5 and SavedModel formats
# --> 366         layer = saving_utils.model_from_config(
#     367             layer_config,
#     368             custom_objects=custom_objects,
#     369         )
#     370     else:
#     371         layer = serialization_lib.deserialize_keras_object(
#     372             layer_config,
#     373             custom_objects=custom_objects,
#     374         )
#
# File c:\Users\KLH\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\legacy\saving\saving_utils.py:83, in model_from_config(config, custom_objects)
#      80         function_dict["config"]["closure"] = function_config[2]
#      81         config["config"]["function"] = function_dict
# ---> 83 return serialization.deserialize_keras_object(
#      84     config,
#      85     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      86     custom_objects=custom_objects,
#      87     printable_module_name="layer",
#      88 )
#
# File c:\Users\KLH\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\legacy\saving\serialization.py:488, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     485 custom_objects = custom_objects or {}
#     487 if "custom_objects" in arg_spec.args:
# --> 488     deserialized_obj = cls.from_config(
#     489         cls_config,
#     490         custom_objects={
#     491             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     492             **custom_objects,
#     493         },
#     494     )
#     495 else:
#     496     with object_registration.CustomObjectScope(custom_objects):
#
# File c:\Users\KLH\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\models\sequential.py:366, in Sequential.from_config(cls, config, custom_objects)
#     362 for layer_config in layer_configs:
#     363     if "module" not in layer_config:
#     364         # Legacy format deserialization (no "module" key)
#     365         # used for H5 and SavedModel formats
# --> 366         layer = saving_utils.model_from_config(
#     367             layer_config,
#     368             custom_objects=custom_objects,
#     369         )
#     370     else:
#     371         layer = serialization_lib.deserialize_keras_object(
#     372             layer_config,
#     373             custom_objects=custom_objects,
#     374         )
#
# File c:\Users\KLH\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\legacy\saving\saving_utils.py:83, in model_from_config(config, custom_objects)
#      80         function_dict["config"]["closure"] = function_config[2]
#      81         config["config"]["function"] = function_dict
# ---> 83 return serialization.deserialize_keras_object(
#      84     config,
#      85     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      86     custom_objects=custom_objects,
#      87     printable_module_name="layer",
#      88 )
#
# File c:\Users\KLH\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\legacy\saving\serialization.py:488, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     485 custom_objects = custom_objects or {}
#     487 if "custom_objects" in arg_spec.args:
# --> 488     deserialized_obj = cls.from_config(
#     489         cls_config,
#     490         custom_objects={
#     491             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     492             **custom_objects,
#     493         },
#     494     )
#     495 else:
#     496     with object_registration.CustomObjectScope(custom_objects):
#
# File c:\Users\KLH\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\models\model.py:823, in Model.from_config(cls, config, custom_objects)
#     818 if is_functional_config and revivable_as_functional:
#     819     # Revive Functional model
#     820     # (but not Functional subclasses with a custom __init__)
#     821     from keras.src.models.functional import functional_from_config
# --> 823     return functional_from_config(
#     824         cls, config, custom_objects=custom_objects
#     825     )
#     827 # Either the model has a custom __init__, or the config
#     828 # does not contain all the information necessary to
#     829 # revive a Functional model. This happens when the user creates
#    (...)    832 # In this case, we fall back to provide all config into the
#     833 # constructor of the class.
#     834 try:
#
# File c:\Users\KLH\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\models\functional.py:561, in functional_from_config(cls, config, custom_objects)
#     559 # First, we create all layers and enqueue nodes to be processed
#     560 for layer_data in functional_config["layers"]:
# --> 561     process_layer(layer_data)
#     563 # Then we process nodes in order of layer depth.
#     564 # Nodes that cannot yet be processed (if the inbound node
#     565 # does not yet exist) are re-enqueued, and the process
#     566 # is repeated until all nodes are processed.
#     567 while unprocessed_nodes:
#
# File c:\Users\KLH\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\models\functional.py:524, in functional_from_config.<locals>.process_layer(layer_data)
#     520 # Instantiate layer.
#     521 if "module" not in layer_data:
#     522     # Legacy format deserialization (no "module" key)
#     523     # used for H5 and SavedModel formats
# --> 524     layer = saving_utils.model_from_config(
#     525         layer_data, custom_objects=custom_objects
#     526     )
#     527 else:
#     528     layer = serialization_lib.deserialize_keras_object(
#     529         layer_data, custom_objects=custom_objects
#     530     )
#
# File c:\Users\KLH\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\legacy\saving\saving_utils.py:83, in model_from_config(config, custom_objects)
#      80         function_dict["config"]["closure"] = function_config[2]
#      81         config["config"]["function"] = function_dict
# ---> 83 return serialization.deserialize_keras_object(
#      84     config,
#      85     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      86     custom_objects=custom_objects,
#      87     printable_module_name="layer",
#      88 )
#
# File c:\Users\KLH\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\legacy\saving\serialization.py:497, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     495     else:
#     496         with object_registration.CustomObjectScope(custom_objects):
# --> 497             deserialized_obj = cls.from_config(cls_config)
#     498 else:
#     499     # Then `cls` may be a function returning a class.
#     500     # in this case by convention `config` holds
#     501     # the kwargs of the function.
#     502     custom_objects = custom_objects or {}
#
# File c:\Users\KLH\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\ops\operation.py:319, in Operation.from_config(cls, config)
#     317     return cls(**config)
#     318 except Exception as e:
# --> 319     raise TypeError(
#     320         f"Error when deserializing class '{cls.__name__}' using "
#     321         f"config={config}.\n\nException encountered: {e}"
#     322     )
#
# TypeError: Error when deserializing class 'DepthwiseConv2D' using config={'name': 'expanded_conv_depthwise', 'trainable': True, 'dtype': 'float32', 'kernel_size': [3, 3], 'strides': [1, 1], 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': [1, 1], 'groups': 1, 'activation': 'linear', 'use_bias': False, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'bias_regularizer': None, 'activity_regularizer': None, 'bias_constraint': None, 'depth_multiplier': 1, 'depthwise_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'depthwise_regularizer': None, 'depthwise_constraint': None}.
#
# Exception encountered: Unrecognized keyword arguments passed to DepthwiseConv2D: {'groups': 1}
